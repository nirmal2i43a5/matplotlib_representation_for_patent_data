# %%
import pandas as pd
import matplotlib.pyplot as plt


data = {


    '2004': [0, 0, 1, 0, 2, 3, 22],
    '2005': [0, 1, 2, 1, 3, 11, 108],
    '2006': [0, 0, 0, 1, 2, 6, 166],
    '2007': [0, 0, 0, 1, 2, 19, 180],
    '2008': [0, 0, 1, 1, 2, 23, 270],
    '2009': [0, 3, 0, 4, 4, 21, 308],
    '2010': [1, 1, 0, 0, 3, 24, 368],
    '2011': [3, 2, 2, 4, 3, 25, 424],
    '2012': [0, 2, 1, 7, 3, 38, 471],
    '2013': [0, 2, 1, 5, 7, 37, 613],
    '2014': [0, 3, 2, 8, 3, 38, 644],
    '2015': [1, 0, 1, 13, 7, 55, 878],
    '2016': [3, 0, 3, 16, 9, 93, 1084],
    '2017': [2, 1, 2, 32, 8, 105, 1117],
    '2018': [2, 2, 2, 42, 6, 134, 1208],
    '2019': [0, 2, 3, 52, 14, 192, 1529],
    '2020': [0, 3, 2, 66, 5, 199, 1547],
    '2021': [0, 2, 0, 76, 12, 185, 1377],
    '2022': [0, 1, 0, 39, 11, 95, 1168]

}


df = pd.DataFrame(data, index=['ISRALE', 'JAPAN', 'CANADA', 'CHINA', 'KOREA', 'EP', 'US'])


for country in df.index:
    fig, ax = plt.subplots(figsize=(8, 12)) 

    # Get the data for the selected country
    counts = df.loc[country]
    years = counts.index

    # Plot the pie chart with counts
    wedges, texts, autotexts = ax.pie(counts, labels=years, autopct='%1.0f%%', startangle=140, wedgeprops={'edgecolor': 'black'})

    # Set aspect of the pie chart to be equal
    ax.axis('equal')

    # Set title
    ax.set_title(f'PATENT COUNTS FOR {country}')

    # Add counts to the pie chart
    for i, autotext in enumerate(autotexts):
        autotext.set_text(f'{counts[i]}')

    # Show the pie chart
    plt.show()
